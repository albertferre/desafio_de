# %%
from utils.data_reader import DataReader
from utils.analyzer import Analyzer

# %%
dr = DataReader()
dr.append_year_data('data/OD_2014.zip','data/Stations_2014.csv')
dr.append_year_data('data/OD_2015.zip','data/Stations_2015.csv')
dr.append_year_data('data/OD_2016.zip','data/Stations_2016.csv')

df = dr.get_data()

# %%
an = Analyzer(df)

# %% [markdown]
# # Obligatorios

# %% [markdown]
# ## Histograma tiempos de viaje
#
# Histograma de tiempos de viaje en segundos

# %%
an.travel_time_hist('2014', plot=True)

# %% [markdown]
# ## Top 10 estaciones

# %% [markdown]
# ### Salida

# %%
an.top_start_stations('2014', plot=True)
# Out:
#                                                 recuento
# Métro Mont-Royal (Rivard / du Mont-Royal)          45600
# de Maisonneuve / de Bleury                         33241
# de Maisonneuve / Stanley                           32055
# Square St-Louis                                    28224
# Mackay /de Maisonneuve (Sud)                       27072
# du Mont-Royal / Clark                              24448
# Métro St-Laurent (de Maisonneuve / St-Laurent)     24274
# St-Dominique / Rachel                              22578
# St-André / Laurier                                 22279
# Marquette / du Mont-Royal                          21799

# %% [markdown]
# ### Llegada

# %%
an.top_end_stations('2014', plot=True)
# Out:
#                                                 recuento
# Métro Mont-Royal (Rivard / du Mont-Royal)          43765
# de Maisonneuve / de Bleury                         39310
# de Maisonneuve / Stanley                           34819
# Métro St-Laurent (de Maisonneuve / St-Laurent)     34664
# Berri / de Maisonneuve                             31664
# St-Urbain / René-Lévesque                          27886
# Mackay /de Maisonneuve (Sud)                       26837
# Square Victoria                                    24032
# Métro Place-d'Armes (Viger / St-Urbain)            23123
# Ste-Catherine / St-Hubert                          21978

# %% [markdown]
# ### Salida/Llegada

# %%
an.top_stations('2014', plot=True)
# Out:
#                                                 recuento
# Métro Mont-Royal (Rivard / du Mont-Royal)          89365
# de Maisonneuve / de Bleury                         72551
# de Maisonneuve / Stanley                           66874
# Métro St-Laurent (de Maisonneuve / St-Laurent)     58938
# Mackay /de Maisonneuve (Sud)                       53909
# Berri / de Maisonneuve                             49417
# Square St-Louis                                    47838
# St-Urbain / René-Lévesque                          46876
# du Mont-Royal / Clark                              45408
# Roy / St-Laurent                                   43330

# %% [markdown]
# ## Top 10 trayectos

# %%
an.top_routes('2014', plot=True)
# Out:
#                                                     recuento
# Métro Jean-Drapeau -> Métro Jean-Drapeau                2853
# de la Commune / Place Jacques-Cartier -> de la ...      1809
# Garnier / du Mont-Royal -> Métro Mont-Royal (Ri...      1670
# Marquette / du Mont-Royal -> Métro Mont-Royal (...      1660
# de Maisonneuve / Stanley -> Mackay /de Maisonne...      1629
# Métro Pie-IX (Pierre-de-Coubertin / Pie-IX) -> ...      1617
# Métro Mont-Royal (Rivard / du Mont-Royal) -> Ga...      1546
# Métro Mont-Royal (Rivard / du Mont-Royal) -> Ma...      1493
# de Maisonneuve / Stanley -> Tupper / Atwater            1413
# Mackay /de Maisonneuve (Sud) -> de Maisonneuve ...      1393

# %% [markdown]
# ## Horas punta

# %%
an.top_hours('2014', plot=True)
# Out:
#     recuento
# 00     54669
# 01     33577
# 02     22248
# 03     18240
# 04      8384
# 05     11685
# 06     37099
# 07    131949
# 08    248511
# 09    149559
# 10    112951
# 11    139446
# 12    168080
# 13    168553
# 14    168181
# 15    195244
# 16    266428
# 17    334800
# 18    250114
# 19    181405
# 20    141183
# 21    117354
# 22     97774
# 23     78842

# %%
# Opcionales

# %%
## Comparación años

# %%
an.year_comparison('2014','2015')
# Out:
# El año 2014 se hicieron -307607 servicios y -99922 horas de servicio en comparación a 2015
# (-307607, -99922.31305555557)
